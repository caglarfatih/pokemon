# %%
import pandas as pd

# %%
print('Hello')
# Out:
# Hello

# %%
print('Papa mozz')
# Out:
# Papa mozz

# %%
i = 1
while i < 6:
    print('Papa mozzz')
    i += 1
# Out:
# Papa mozzz
# Papa mozzz
# Papa mozzz
# Papa mozzz
# Papa mozzz

# %%
import pandas as pd
df = pd.read_csv(r'C:\Users\LEGION\Desktop\pokemon.csv')
print(df)
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
print(df.columns)
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
print(df['Name'])
# Out:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object

# %%
print(df.Name)
# Out:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object

# %%
print(df[['Name','Type 1','Type 2']])
# Out:
#                       Name   Type 1  Type 2
# 0                Bulbasaur    Grass  Poison
# 1                  Ivysaur    Grass  Poison
# 2                 Venusaur    Grass  Poison
# 3    VenusaurMega Venusaur    Grass  Poison
# 4               Charmander     Fire     NaN
# ..                     ...      ...     ...
# 795                Diancie     Rock   Fairy
# 796    DiancieMega Diancie     Rock   Fairy
# 797    HoopaHoopa Confined  Psychic   Ghost
# 798     HoopaHoopa Unbound  Psychic    Dark
# 799              Volcanion     Fire   Water
#
# [800 rows x 3 columns]

# %%
print(df.iloc[1:5]) 
#specific location
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
print(df.iloc[2,1])
#specific data
# Out:
# Venusaur

# %%
for index,row in df.iterrows():
    print(index,row['Name'])
    #prints index and row and if written, row might be specific one as well
# Out:
# 0 Bulbasaur
# 1 Ivysaur
# 2 Venusaur
# 3 VenusaurMega Venusaur
# 4 Charmander
# 5 Charmeleon
# 6 Charizard
# 7 CharizardMega Charizard X
# 8 CharizardMega Charizard Y
# 9 Squirtle
# 10 Wartortle
# 11 Blastoise
# 12 BlastoiseMega Blastoise
# 13 Caterpie
# 14 Metapod
# 15 Butterfree
# 16 Weedle
# 17 Kakuna
# 18 Beedrill
# 19 BeedrillMega Beedrill
# 20 Pidgey
# 21 Pidgeotto
# 22 Pidgeot
# 23 PidgeotMega Pidgeot
# 24 Rattata
# 25 Raticate
# 26 Spearow
# 27 Fearow
# 28 Ekans
# 29 Arbok
# 30 Pikachu
# 31 Raichu
# 32 Sandshrew
# 33 Sandslash
# 34 Nidoran♀
# 35 Nidorina
# 36 Nidoqueen
# 37 Nidoran♂
# 38 Nidorino
# 39 Nidoking
# 40 Clefairy
# 41 Clefable
# 42 Vulpix
# 43 Ninetales
# 44 Jigglypuff
# 45 Wigglytuff
# 46 Zubat
# 47 Golbat
# 48 Oddish
# 49 Gloom
# 50 Vileplume
# 51 Paras
# 52 Parasect
# 53 Venonat
# 54 Venomoth
# 55 Diglett
# 56 Dugtrio
# 57 Meowth
# 58 Persian
# 59 Psyduck
# 60 Golduck
# 61 Mankey
# 62 Primeape
# 63 Growlithe
# 64 Arcanine
# 65 Poliwag
# 66 Poliwhirl
# ...

# %%
df.loc[df['Type 1'] == 'Fire']
# Out:
#        #                       Name Type 1    Type 2  Total   HP  Attack  \
# 4      4                 Charmander   Fire       NaN    309   39      52
# 5      5                 Charmeleon   Fire       NaN    405   58      64
# 6      6                  Charizard   Fire    Flying    534   78      84
# 7      6  CharizardMega Charizard X   Fire    Dragon    634   78     130
# 8      6  CharizardMega Charizard Y   Fire    Flying    634   78     104
# 42    37                     Vulpix   Fire       NaN    299   38      41
# 43    38                  Ninetales   Fire       NaN    505   73      76
# 63    58                  Growlithe   Fire       NaN    350   55      70
# 64    59                   Arcanine   Fire       NaN    555   90     110
# 83    77                     Ponyta   Fire       NaN    410   50      85
# 84    78                   Rapidash   Fire       NaN    500   65     100
# 135  126                     Magmar   Fire       NaN    495   65      95
# ...

# %%
df.sort_values('Name', ascending=False)
# Out:
#        #                     Name   Type 1  Type 2  Total   HP  Attack  \
# 794  718         Zygarde50% Forme   Dragon  Ground    600  108     100
# 695  634                 Zweilous     Dark  Dragon    420   72      85
# 46    41                    Zubat   Poison  Flying    245   40      45
# 631  570                    Zorua     Dark     NaN    330   40      65
# 632  571                  Zoroark     Dark     NaN    510   60     105
# ..   ...                      ...      ...     ...    ...  ...     ...
# 393  359          AbsolMega Absol     Dark     NaN    565   65     150
# 392  359                    Absol     Dark     NaN    465   65     130
# 68    63                     Abra  Psychic     NaN    310   25      20
# 511  460  AbomasnowMega Abomasnow    Grass     Ice    594   90     132
# 510  460                Abomasnow    Grass     Ice    494   90      92
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.sort_values('HP' , ascending=False)
# Out:
#        #       Name   Type 1 Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 261  242    Blissey   Normal    NaN    540  255      10       10       75
# 121  113    Chansey   Normal    NaN    450  250       5        5       35
# 217  202  Wobbuffet  Psychic    NaN    405  190      33       58       33
# 351  321    Wailord    Water    NaN    500  170      90       45       90
# 655  594  Alomomola    Water    NaN    470  165      75       80       40
# ..   ...        ...      ...    ...    ...  ...     ...      ...      ...
# 139  129   Magikarp    Water    NaN    200   20      10       55       15
# 381  349     Feebas    Water    NaN    200   20      15       20       10
# 388  355    Duskull    Ghost    NaN    295   20      40       90       30
# 55    50    Diglett   Ground    NaN    265   10      55       25       35
# 316  292   Shedinja      Bug  Ghost    236    1      90       45       30
#
#      Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.sort_values('HP')
# Out:
#        #       Name   Type 1 Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 316  292   Shedinja      Bug  Ghost    236    1      90       45       30
# 55    50    Diglett   Ground    NaN    265   10      55       25       35
# 139  129   Magikarp    Water    NaN    200   20      10       55       15
# 388  355    Duskull    Ghost    NaN    295   20      40       90       30
# 487  439   Mime Jr.  Psychic  Fairy    310   20      25       45       70
# ..   ...        ...      ...    ...    ...  ...     ...      ...      ...
# 655  594  Alomomola    Water    NaN    470  165      75       80       40
# 351  321    Wailord    Water    NaN    500  170      90       45       90
# 217  202  Wobbuffet  Psychic    NaN    405  190      33       58       33
# 121  113    Chansey   Normal    NaN    450  250       5        5       35
# 261  242    Blissey   Normal    NaN    540  255      10       10       75
#
#      Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.sort_values(['Type 1','Name','HP'], ascending=True)
# Out:
#        #                   Name Type 1  Type 2  Total   HP  Attack  Defense  \
# 678  617               Accelgor    Bug     NaN    495   80      70       40
# 182  168                Ariados    Bug  Poison    390   70      90       70
# 290  267              Beautifly    Bug  Flying    395   60      70       50
# 18    15               Beedrill    Bug  Poison    395   65      90       40
# 19    15  BeedrillMega Beedrill    Bug  Poison    495   65     150       40
# ..   ...                    ...    ...     ...    ...  ...     ...      ...
# 351  321                Wailord  Water     NaN    500  170      90       45
# 10     8              Wartortle  Water     NaN    405   59      63       80
# 372  340               Whiscash  Water  Ground    468  110      78       73
# 301  278                Wingull  Water  Flying    270   40      30       30
# 209  194                 Wooper  Water  Ground    210   55      45       45
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.sort_values(['Type 1','HP'], ascending=False)
# Out:
#        #       Name Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 351  321    Wailord  Water     NaN    500  170      90       45       90
# 655  594  Alomomola  Water     NaN    470  165      75       80       40
# 142  131     Lapras  Water     Ice    535  130      85       80       85
# 145  134   Vaporeon  Water     NaN    525  130      65       60      110
# 350  320    Wailmer  Water     NaN    400  130      70       35       70
# ..   ...        ...    ...     ...    ...  ...     ...      ...      ...
# 314  290    Nincada    Bug  Ground    266   31      45       90       30
# 462  415     Combee    Bug  Flying    244   30      30       42       30
# 603  543   Venipede    Bug  Poison    260   30      45       59       30
# 230  213    Shuckle    Bug    Rock    505   20      10      230       10
# 316  292   Shedinja    Bug   Ghost    236    1      90       45       30
#
#      Sp. Def  Speed  Generation  Legendary
# 351       45     60           3      False
# ...

# %%
#first one ascending the second is descending vice-v           
df.sort_values(['Name','HP'],ascending=[0,1])
# Out:
#        #                     Name   Type 1  Type 2  Total   HP  Attack  \
# 794  718         Zygarde50% Forme   Dragon  Ground    600  108     100
# 695  634                 Zweilous     Dark  Dragon    420   72      85
# 46    41                    Zubat   Poison  Flying    245   40      45
# 631  570                    Zorua     Dark     NaN    330   40      65
# 632  571                  Zoroark     Dark     NaN    510   60     105
# ..   ...                      ...      ...     ...    ...  ...     ...
# 393  359          AbsolMega Absol     Dark     NaN    565   65     150
# 392  359                    Absol     Dark     NaN    465   65     130
# 68    63                     Abra  Psychic     NaN    310   25      20
# 511  460  AbomasnowMega Abomasnow    Grass     Ice    594   90     132
# 510  460                Abomasnow    Grass     Ice    494   90      92
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.head(5)
#print until 5th ?
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
df['Sum up'] = df['HP'] + df['Attack'] + df['Defense'] + df['Sp. Atk'] + df['Sp. Def'] + df['Speed']
df.head(8)

#adding a new column
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary  Sum up
# 0       65       65     45           1      False     318
# 1       80       80     60           1      False     405
# 2      100      100     80           1      False     525
# 3      122      120     80           1      False     625
# ...

# %%
#-1 is a reverse index
cols = list(df.columns)
df = df[cols[0:4]+[cols[-1]]+cols[4:12]]
df.head(7)
# Out:
#    #                   Name Type 1  Type 2  Sum up  Total  HP  Attack  \
# 0  1              Bulbasaur  Grass  Poison     318    318  45      49
# 1  2                Ivysaur  Grass  Poison     405    405  60      62
# 2  3               Venusaur  Grass  Poison     525    525  80      82
# 3  3  VenusaurMega Venusaur  Grass  Poison     625    625  80     100
# 4  4             Charmander   Fire     NaN     309    309  39      52
# 5  5             Charmeleon   Fire     NaN     405    405  58      64
# 6  6              Charizard   Fire  Flying     534    534  78      84
#
#    Defense  Sp. Atk  Sp. Def  Speed  Generation
# 0       49       65       65     45           1
# 1       63       80       80     60           1
# 2       83      100      100     80           1
# 3      123      122      120     80           1
# 4       43       60       50     65           1
# 5       58       80       65     80           1
# 6       78      109       85    100           1

# %%
df.to_csv('modified.csv', index=False)

# %%
df.to_excel('modify.xlsx', index=False) 
#to create an excel file

# %%
df.to_csv('modified.csv', sep='\t')

# %%
df.loc[(df['Type 1'] =='Grass') & (df['Type 2'] =='Poison') & (df['HP'] > 70)]
#just parsing which information is being asked
# Out:
#        #                   Name Type 1  Type 2  Sum up  Total   HP  Attack  \
# 2      3               Venusaur  Grass  Poison     525    525   80      82
# 3      3  VenusaurMega Venusaur  Grass  Poison     625    625   80     100
# 50    45              Vileplume  Grass  Poison     490    490   75      80
# 77    71             Victreebel  Grass  Poison     490    490   80     105
# 652  591              Amoonguss  Grass  Poison     464    464  114      85
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation
# 2         83      100      100     80           1
# 3        123      122      120     80           1
# 50        85      110       90     50           1
# 77        65      100       70     70           1
# 652       70       85       80     30           5

# %%
new_df = df.loc[(df['Type 1'] =='Grass') & (df['Type 2'] =='Poison') & (df['HP'] > 70)]
new_df
# Out:
#        #                   Name Type 1  Type 2  Sum up  Total   HP  Attack  \
# 2      3               Venusaur  Grass  Poison     525    525   80      82
# 3      3  VenusaurMega Venusaur  Grass  Poison     625    625   80     100
# 50    45              Vileplume  Grass  Poison     490    490   75      80
# 77    71             Victreebel  Grass  Poison     490    490   80     105
# 652  591              Amoonguss  Grass  Poison     464    464  114      85
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation
# 2         83      100      100     80           1
# 3        123      122      120     80           1
# 50        85      110       90     50           1
# 77        65      100       70     70           1
# 652       70       85       80     30           5

# %%
#filtering name
df.loc[~df['Name'].str.contains('Mega')]
# Out:
#        #                 Name   Type 1  Type 2  Sum up  Total   HP  Attack  \
# 0      1            Bulbasaur    Grass  Poison     318    318   45      49
# 1      2              Ivysaur    Grass  Poison     405    405   60      62
# 2      3             Venusaur    Grass  Poison     525    525   80      82
# 4      4           Charmander     Fire     NaN     309    309   39      52
# 5      5           Charmeleon     Fire     NaN     405    405   58      64
# ..   ...                  ...      ...     ...     ...    ...  ...     ...
# 794  718     Zygarde50% Forme   Dragon  Ground     600    600  108     100
# 795  719              Diancie     Rock   Fairy     600    600   50     100
# 797  720  HoopaHoopa Confined  Psychic   Ghost     600    600   80     110
# 798  720   HoopaHoopa Unbound  Psychic    Dark     680    680   80     160
# 799  721            Volcanion     Fire   Water     600    600   80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation
# ...

# %%
df.loc[~df['Type 1'].str.contains('Grass')]
# Out:
#        #                       Name   Type 1  Type 2  Sum up  Total  HP  \
# 4      4                 Charmander     Fire     NaN     309    309  39
# 5      5                 Charmeleon     Fire     NaN     405    405  58
# 6      6                  Charizard     Fire  Flying     534    534  78
# 7      6  CharizardMega Charizard X     Fire  Dragon     634    634  78
# 8      6  CharizardMega Charizard Y     Fire  Flying     634    634  78
# ..   ...                        ...      ...     ...     ...    ...  ..
# 795  719                    Diancie     Rock   Fairy     600    600  50
# 796  719        DiancieMega Diancie     Rock   Fairy     700    700  50
# 797  720        HoopaHoopa Confined  Psychic   Ghost     600    600  80
# 798  720         HoopaHoopa Unbound  Psychic    Dark     680    680  80
# 799  721                  Volcanion     Fire   Water     600    600  80
#
#      Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation
# ...

# %%
df.loc[~df['Type 1'].str.contains('Grass|Fire')]
# Out:
#        #                     Name   Type 1  Type 2  Sum up  Total   HP  \
# 9      7                 Squirtle    Water     NaN     314    314   44
# 10     8                Wartortle    Water     NaN     405    405   59
# 11     9                Blastoise    Water     NaN     530    530   79
# 12     9  BlastoiseMega Blastoise    Water     NaN     630    630   79
# 13    10                 Caterpie      Bug     NaN     195    195   45
# ..   ...                      ...      ...     ...     ...    ...  ...
# 794  718         Zygarde50% Forme   Dragon  Ground     600    600  108
# 795  719                  Diancie     Rock   Fairy     600    600   50
# 796  719      DiancieMega Diancie     Rock   Fairy     700    700   50
# 797  720      HoopaHoopa Confined  Psychic   Ghost     600    600   80
# 798  720       HoopaHoopa Unbound  Psychic    Dark     680    680   80
#
#      Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation
# ...

# %%
import re
df.loc[df['Name'].str.contains('pi[a-z]*')]
       #star means 0, more
     #all names contain 'Pİ'
        #add ^ if just start with 'Pİ'
# Out:
#        #        Name   Type 1  Type 2  Sum up  Total   HP  Attack  Defense  \
# 13    10    Caterpie      Bug     NaN     195    195   45      30       35
# 42    37      Vulpix     Fire     NaN     299    299   38      41       40
# 76    70  Weepinbell    Grass  Poison     390    390   65      90       50
# 84    78    Rapidash     Fire     NaN     500    500   65     100       70
# 181  167    Spinarak      Bug  Poison     250    250   40      60       40
# 189  175      Togepi    Fairy     NaN     245    245   35      20       65
# 202  187      Hoppip    Grass  Flying     250    250   35      35       40
# 266  247     Pupitar     Rock  Ground     410    410   70      84       70
# 345  316      Gulpin   Poison     NaN     302    302   70      43       53
# 357  326     Grumpig  Psychic     NaN     470    470   80      45       65
# 358  327      Spinda   Normal     NaN     360    360   60      60       60
# ...

# %%
import re
df.loc[df['Name'].str.contains('^Pi[a-z]*')]
# Out:
#        #                 Name    Type 1    Type 2  Sum up  Total   HP  Attack  \
# 20    16               Pidgey    Normal    Flying     251    251   40      45
# 21    17            Pidgeotto    Normal    Flying     349    349   63      60
# 22    18              Pidgeot    Normal    Flying     479    479   83      80
# 23    18  PidgeotMega Pidgeot    Normal    Flying     579    579   83      80
# 30    25              Pikachu  Electric       NaN     320    320   35      55
# 136  127               Pinsir       Bug       NaN     500    500   65     125
# 137  127    PinsirMega Pinsir       Bug    Flying     600    600   65     155
# 186  172                Pichu  Electric       NaN     205    205   20      40
# 219  204               Pineco       Bug       NaN     290    290   50      65
# 239  221            Piloswine       Ice    Ground     450    450  100     100
# 438  393               Piplup     Water       NaN     314    314   53      51
# ...

# %%
import re

# %%
df.loc[df['Name'].str.contains('^pi[a-z]*', flags=re.I, regex=True)] 
#clears the error list due low&upp-er case
# Out:
#        #                 Name    Type 1    Type 2  Sum up  Total   HP  Attack  \
# 20    16               Pidgey    Normal    Flying     251    251   40      45
# 21    17            Pidgeotto    Normal    Flying     349    349   63      60
# 22    18              Pidgeot    Normal    Flying     479    479   83      80
# 23    18  PidgeotMega Pidgeot    Normal    Flying     579    579   83      80
# 30    25              Pikachu  Electric       NaN     320    320   35      55
# 136  127               Pinsir       Bug       NaN     500    500   65     125
# 137  127    PinsirMega Pinsir       Bug    Flying     600    600   65     155
# 186  172                Pichu  Electric       NaN     205    205   20      40
# 219  204               Pineco       Bug       NaN     290    290   50      65
# 239  221            Piloswine       Ice    Ground     450    450  100     100
# 438  393               Piplup     Water       NaN     314    314   53      51
# ...

# %%
df.loc[df['Name'].str.contains('^pi|^le[a-z]*', flags=re.I, regex=True)]
# Out:
#        #                 Name    Type 1    Type 2  Sum up  Total   HP  Attack  \
# 20    16               Pidgey    Normal    Flying     251    251   40      45
# 21    17            Pidgeotto    Normal    Flying     349    349   63      60
# 22    18              Pidgeot    Normal    Flying     479    479   83      80
# 23    18  PidgeotMega Pidgeot    Normal    Flying     579    579   83      80
# 30    25              Pikachu  Electric       NaN     320    320   35      55
# 136  127               Pinsir       Bug       NaN     500    500   65     125
# 137  127    PinsirMega Pinsir       Bug    Flying     600    600   65     155
# 179  165               Ledyba       Bug    Flying     265    265   40      20
# 180  166               Ledian       Bug    Flying     390    390   55      35
# 186  172                Pichu  Electric       NaN     205    205   20      40
# 219  204               Pineco       Bug       NaN     290    290   50      65
# ...
